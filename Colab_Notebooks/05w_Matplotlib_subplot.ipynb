# %% [markdown]
# <a href="https://colab.research.google.com/github/huiminPark/huimin/blob/main/Colab_Notebooks/05w_Matplotlib_subplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.plot([10, 5, 25, 30, 20])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([10, 5, 25, 30, 20])
plt.show()

# %%
plt.rcParams['figure.figsize']
# Out:
# [6.4, 4.8]

# %%
plt.rcParams['figure.figsize'] = (5.2, 4.8)
plt.rcParams['figure.figsize']
# Out:
# [5.2, 4.8]

# %%
plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams['figure.figsize']
# Out:
# [6.4, 4.8]

# %%
plt.rcParams['figure.figsize'] = (5, 3)

# %%
import matplotlib.pyplot as plt
plt.plot([1, 3, 5, 7, 9], [8, 6, 17, 22, 3])
plt.title('직선 그래프 그리기')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51649 (\N{HANGUL SYLLABLE JIG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
# ...

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y, marker='o', linestyle='None', color='b', label='소수(Prime Numbers)')

plt.xlabel('X-축(axis)')
plt.ylabel('Y-축(axis)')
plt.title('소수 그리기(Prime Numbers Plot)')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from font(s) DejaVu Sans.
# ...

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [10, 20, 38, 40], color='r', linestyle='-', marker='d', linewidth=3, label="thick line")
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'b', ls='--', marker='o', lw=0.5, label='thin line')
plt.title('속성 marker linewidth linestyle')
plt.xlabel('X축(axis)')
plt.ylabel('Y축(axis)')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
import matplotlib.pyplot as plt
#Fixing random state for reproducibility
np.random.seed(2025)
N = 80
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (20 * np.random.rand(N)) ** 2 #0 to 15 point radi
plt.scatter(x, y, s=area, c=colors, alpha=0.7)
plt.colorbar()
plt.show()

# %%
import numpy as np
x = np.random.randint(-10, 10, 10)
print(x)
print(x > 0)
print(x[x > 0])
# Out:
# [ -3  -4   1  -1   3   7  -9  -8   4 -10]
# [False False  True False  True  True False False  True False]
# [1 3 7 4]

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randint(-100, 100, 1000)
y = np.random.randint(-100, 100, 1000)
mask1 = abs(x) > 50
mask2 = abs(y) > 50
x = x[mask1 + mask2]
y = y[mask1 + mask2]
plt.scatter(x, y, c=x, cmap="jet", alpha=0.4)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randint(-100, 100, 1000)
y = np.random.randint(-100, 100, 1000)
mask1 = abs(x) > 50
mask2 = abs(y) > 50
# Apply the same mask to both x and y to ensure they have the same size
combined_mask = mask1 & mask2 # or mask1 | mask2 depending on desired filtering
x = x[combined_mask]
y = y[combined_mask]
plt.scatter(x, y, c=x, cmap='jet', alpha = 0.5)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(["Red", "Green", "Blue"], [8, 5, 10])
plt.show()

# %%
import matplotlib.pyplot as plt
c = ["red", "green", "blue"]
plt.bar(c, [10, 4, 12], color=c, alpha=.4)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4)) # 그림 크기 지정
plt.hist([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, 6], rwidth=.98, bins=[.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5])
plt.xticks(range(1, 7))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
dice = np.random.choice(range (1, 7), 1000000, p=[0.15, 0.25, 0.3, 0.1, 0.1, 0.1])
plt.figure(figsize=(5, 3), dpi=200)
plt.hist(dice, rwidth=.98, bins=np.arange(.5, 7))
plt.xticks(range(1, 7))
plt.savefig('주사위.png')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(9, 4))
plt.subplot(2, 3, 1)
plt.plot([1, 2, 3])
plt.subplot(2, 3, 5)
plt.subplot(2, 3, 6)
plt.plot([5, 4, 3])
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 4)
fig.set_size_inches((9,4))

axs[0,1].plot([5,1,3])
axs[1,0].plot([3,3,1])
plt.plot([10,5,20])
plt.show()

# %%
import matplotlib.pyplot as plt


plt.suptitle('전체 제목', fontsize=14, y=-1.02)

plt.subplot(2, 3, 1)
plt.plot([1, 4, 9, 16])
plt.title('제곱수')

plt.subplot (2, 3, 6)
plt.plot([1, 2, 3, 4])
plt.title('선형')

plt.subplot(2, 3, 2)
plt.plot([6, 5, 2, 1])
plt.title('감소')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_6903/3038632401.py:18: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/3038632401.py:18: UserWarning: Glyph 44273 (\N{HANGUL SYLLABLE GOB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/3038632401.py:18: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/3038632401.py:18: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/3038632401.py:18: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/3038632401.py:18: UserWarning: Glyph 44048 (\N{HANGUL SYLLABLE GAM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots (2, 3, figsize=(7, 4))
fig.set_size_inches (6,3)
ax[0, 1].plot([1, 4, 9, 16])
ax [1, 0].plot([1, 2, 3, 4])
ax [1, 2].plot([6, 5, 2, 1])

fig.suptitle('전체 제목', fontsize=14, fontweight= 'bold')

ax[0, 0].set_title('(0,0) 빈 플롯')
ax[0, 1].set_title ('(0, 1) 제곱수')
ax[0, 2].set_title('(0,2) 빈 플롯')
ax [1, 0].set_title(' (1,0) 선형')
ax[1, 1].set_title(' (1,1) 빈 플롯')
ax [1, 2].set_title(' (1,2) 감소')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_6903/3199452228.py:16: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/3199452228.py:16: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/3199452228.py:16: UserWarning: Glyph 47215 (\N{HANGUL SYLLABLE ROS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/3199452228.py:16: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/3199452228.py:16: UserWarning: Glyph 44273 (\N{HANGUL SYLLABLE GOB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/3199452228.py:16: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6, 4))
ax1 = fig.add_subplot(231)
ax1.plot([1, 4, 9, 16])
ax1.set_title('제곱수')
ax2 = fig.add_subplot(233)
ax2.plot([1, 2, 3, 4])
ax2.set_title('선형')
ax3 = fig.add_subplot(235)
ax3.plot([6, 5, 2, 1])
ax3.set_title('감소')
fig.suptitle('전체 제목', fontsize = 14)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_6903/4044095475.py:13: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/4044095475.py:13: UserWarning: Glyph 44273 (\N{HANGUL SYLLABLE GOB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/4044095475.py:13: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/4044095475.py:13: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/4044095475.py:13: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_6903/4044095475.py:13: UserWarning: Glyph 44048 (\N{HANGUL SYLLABLE GAM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
import pandas as pd
age = pd.Series([9, 17, 32, 45, 65, 98], index=list('abcdef'), name='age')
age
# Out:
# a     9
# b    17
# c    32
# d    45
# e    65
# f    98
# Name: age, dtype: int64

# %%
age['b']
# Out:
# np.int64(17)

# %%
age[[1, 3, 5]]
# Out:
# /tmp/ipykernel_6903/1546391730.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   age[[1, 3, 5]]
# b    17
# d    45
# f    98
# Name: age, dtype: int64

# %%
age[['a', 'f', 'd']]
# Out:
# a     9
# f    98
# d    45
# Name: age, dtype: int64

# %%
age[['c']]
# Out:
# c    32
# Name: age, dtype: int64

# %%
import pandas as pd
s = pd.Series ([3, 6, - 3, 0, - 4, 8, - 7])
s
# Out:
# 0    3
# 1    6
# 2   -3
# 3    0
# 4   -4
# 5    8
# 6   -7
# dtype: int64

# %%
import numpy as np
import pandas as pd
names = ['희빈', '수영', '현수', '지호', '지민']
p = pd.Series([99, 84, 92, 65, 78], index=names)
p
# Out:
# 희빈    99
# 수영    84
# 현수    92
# 지호    65
# 지민    78
# dtype: int64

# %%
p.name = '수학성적'
p.index.name = 'st_name'
p
# Out:
# st_name
# 희빈    99
# 수영    84
# 현수    92
# 지호    65
# 지민    78
# Name: 수학성적, dtype: int64

# %%
p.sort_values()
# Out:
# st_name
# 지호    65
# 지민    78
# 수영    84
# 현수    92
# 희빈    99
# Name: 수학성적, dtype: int64

# %%
p.sort_values(ascending=False)
# Out:
# st_name
# 희빈    99
# 현수    92
# 수영    84
# 지민    78
# 지호    65
# Name: 수학성적, dtype: int64

# %%
p.sort_index()
# Out:
# st_name
# 수영    84
# 지민    78
# 지호    65
# 현수    92
# 희빈    99
# Name: 수학성적, dtype: int64

# %%
p.sort_index(ascending=False)
# Out:
# st_name
# 희빈    99
# 현수    92
# 지호    65
# 지민    78
# 수영    84
# Name: 수학성적, dtype: int64
